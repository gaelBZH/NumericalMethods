# %% [markdown]
# <a href="https://colab.research.google.com/github/gaelBZH/NumericalMethods/blob/main/Personal_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Numerical Analysis
# ## Gaël Kerninon's Collab x GitHub Personal NoteBook

# %%
print("Hello, world !")
# Out:
# Hello, world
